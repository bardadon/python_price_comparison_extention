# %%
from CollectProductData import CollectProductData

url = 'https://api.imgflip.com/get_memes'
crawler = CollectProductData()
soup = crawler.sendHTTP(url)
meme_df = crawler.getMemeName(soup)
meme_df
# Out:
#            id                                   name  \
# 0   371619279                    Megamind no bitches
# 1   370867422                       Megamind peeking
# 2   342785297          Gus Fring we are not the same
# 3   322841258                   Anakin Padme 4 Panel
# 4   316989420         Average Fan vs Average Enjoyer
# ..        ...                                    ...
# 95      61556             Grandma Finds The Internet
# 96      61544                            Success Kid
# 97      61532  The Most Interesting Man In The World
# 98      61520                           Futurama Fry
# 99      21735                       The Rock Driving
#
#                                  url  width  height  box_count  captions
# 0   https://i.imgflip.com/65939r.jpg    674     734          2         0
# 1   https://i.imgflip.com/64sz4u.png    540     540          2         0
# 2   https://i.imgflip.com/5o32tt.png    700    1000          3         0
# ...

# %%
"They *don't know".strip('*')
# Out:
# "They *don't know"

# %%
meme_df['name'] = meme_df.name.str.replace("'", '')
meme_df.name.head(25)
# Out:
# 0                                   Megamind no bitches
# 1                                      Megamind peeking
# 2                         Gus Fring we are not the same
# 3                                  Anakin Padme 4 Panel
# 4                        Average Fan vs Average Enjoyer
# 5                                          where monkey
# 6     Gentlemen, it is with great pleasure to inform...
# 7                                           Trade Offer
# 8                                        They dont know
# 9                                          Laughing Leo
# 10               Mother Ignoring Kid Drowning In A Pool
# 11                                      Always Has Been
# 12                                 Bugs bunny communist
# 13                                 Buff Doge vs. Cheems
# 14                         A train hitting a school bus
# 15                               AJ Styles & Undertaker
# 16                                     Panik Kalm Panik
# ...
